# %%
import pickle

model_path = "../model/model.pkl"

with open(model_path, "rb") as f:
    model = pickle.load(f)

print(f"Model expects {model.n_features_in_} features.")
# Out:
# Model expects 400 features.

# %%
import pickle

features_path = "../LUPEAPP_processed_dataset/Test/binned_features_Test.pkl"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 import pickle
#       3 features_path = "../LUPEAPP_processed_dataset/Test/binned_features_Test.pkl"
# ----> 5 with open(features_path, "rb") as f:
#       6     features = pickle.load(f)
#
# File ~/GitHub/LUPE 2.0 App/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../LUPEAPP_processed_dataset/Test/binned_features_Test.pkl'

# %%
feature_data = features[group_name][condition_name][file_name][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 feature_data = features[group_name][condition_name][file_name][0]
#
# NameError: name 'features' is not defined

# %%
import pickle

features_path = "../LUPEAPP_processed_dataset/Test/binned_features_Test.pkl"

with open(features_path, "rb") as f:
    features = pickle.load(f)

# Example group and condition from your setup
group_name = "Group1"
condition_name = "CSO17"
file_name = list(features[group_name][condition_name].keys())[0]

feature_data = features[group_name][condition_name][file_name][0]
print(f"Feature shape: {feature_data.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 import pickle
#       3 features_path = "../LUPEAPP_processed_dataset/Test/binned_features_Test.pkl"
# ----> 5 with open(features_path, "rb") as f:
#       6     features = pickle.load(f)
#       8 # Example group and condition from your setup
#
# File ~/GitHub/LUPE 2.0 App/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# ...
